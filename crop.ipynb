# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
crop=pd.read_csv(r"D:\Harvest AI\crop_yield.csv")
crop
# Out:
#                 Crop  Crop_Year       Season              State      Area  \
# 0           Arecanut       1997  Whole Year               Assam   73814.0
# 1          Arhar/Tur       1997  Kharif                   Assam    6637.0
# 2        Castor seed       1997  Kharif                   Assam     796.0
# 3           Coconut        1997  Whole Year               Assam   19656.0
# 4       Cotton(lint)       1997  Kharif                   Assam    1739.0
# ...              ...        ...          ...                ...       ...
# 19684  Small millets       1998  Kharif                Nagaland    4000.0
# 19685          Wheat       1998  Rabi                  Nagaland    1000.0
# 19686          Maize       1997  Kharif       Jammu and Kashmir  310883.0
# 19687           Rice       1997  Kharif       Jammu and Kashmir  275746.0
# 19688          Wheat       1997  Rabi         Jammu and Kashmir  239344.0
#
#        Production  Annual_Rainfall   Fertilizer  Pesticide        Yield
# ...

# %% [markdown]
# # New Section

# %%
crop.head()
# Out:
#            Crop  Crop_Year       Season  State     Area  Production  \
# 0      Arecanut       1997  Whole Year   Assam  73814.0       56708
# 1     Arhar/Tur       1997  Kharif       Assam   6637.0        4685
# 2   Castor seed       1997  Kharif       Assam    796.0          22
# 3      Coconut        1997  Whole Year   Assam  19656.0   126905000
# 4  Cotton(lint)       1997  Kharif       Assam   1739.0         794
#
#    Annual_Rainfall  Fertilizer  Pesticide        Yield
# 0           2051.4  7024878.38   22882.34     0.796087
# 1           2051.4   631643.29    2057.47     0.710435
# 2           2051.4    75755.32     246.76     0.238333
# 3           2051.4  1870661.52    6093.36  5238.051739
# 4           2051.4   165500.63     539.09     0.420909

# %%
crop.isnull().sum()
# Out:
# Crop               0
# Crop_Year          0
# Season             0
# State              0
# Area               0
# Production         0
# Annual_Rainfall    0
# Fertilizer         0
# Pesticide          0
# Yield              0
# dtype: int64

# %%
crop.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 19689 entries, 0 to 19688
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Crop             19689 non-null  str
#  1   Crop_Year        19689 non-null  int64
#  2   Season           19689 non-null  str
#  3   State            19689 non-null  str
#  4   Area             19689 non-null  float64
#  5   Production       19689 non-null  int64
#  6   Annual_Rainfall  19689 non-null  float64
#  7   Fertilizer       19689 non-null  float64
#  8   Pesticide        19689 non-null  float64
#  9   Yield            19689 non-null  float64
# dtypes: float64(5), int64(2), str(3)
# memory usage: 1.5 MB

# %%
crop.dtypes
# Out:
# Crop                   str
# Crop_Year            int64
# Season                 str
# State                  str
# Area               float64
# Production           int64
# Annual_Rainfall    float64
# Fertilizer         float64
# Pesticide          float64
# Yield              float64
# dtype: object

# %%
d=crop.describe(include="all")
d
# Out:
#          Crop     Crop_Year       Season      State          Area  \
# count   19689  19689.000000        19689      19689  1.968900e+04
# unique     55           NaN            6         30           NaN
# top      Rice           NaN  Kharif       Karnataka           NaN
# freq     1197           NaN         8232       1432           NaN
# mean      NaN   2009.127584          NaN        NaN  1.799266e+05
# std       NaN      6.498099          NaN        NaN  7.328287e+05
# min       NaN   1997.000000          NaN        NaN  5.000000e-01
# 25%       NaN   2004.000000          NaN        NaN  1.390000e+03
# 50%       NaN   2010.000000          NaN        NaN  9.317000e+03
# 75%       NaN   2015.000000          NaN        NaN  7.511200e+04
# max       NaN   2020.000000          NaN        NaN  5.080810e+07
#
#           Production  Annual_Rainfall    Fertilizer     Pesticide  \
# count   1.968900e+04     19689.000000  1.968900e+04  1.968900e+04
# ...

# %%
print(crop.columns)
# Out:
# Index(['Crop', 'Crop_Year', 'Season', 'State', 'Area', 'Production',
#        'Annual_Rainfall', 'Fertilizer', 'Pesticide', 'Yield'],
#       dtype='str')

# %%
crop.isnull().sum()
# Out:
# Crop               0
# Crop_Year          0
# Season             0
# State              0
# Area               0
# Production         0
# Annual_Rainfall    0
# Fertilizer         0
# Pesticide          0
# Yield              0
# dtype: int64

# %%
for i in crop.columns:
    print(i,':','\n',crop[i].unique(),'\n')
# Out:
# Crop :
#  <StringArray>
# [             'Arecanut',             'Arhar/Tur',           'Castor seed',
#               'Coconut ',          'Cotton(lint)',          'Dry chillies',
#                   'Gram',                  'Jute',               'Linseed',
#                  'Maize',                 'Mesta',            'Niger seed',
#                  'Onion',    'Other  Rabi pulses',                'Potato',
#      'Rapeseed &Mustard',                  'Rice',               'Sesamum',
#          'Small millets',             'Sugarcane',          'Sweet potato',
#                'Tapioca',               'Tobacco',              'Turmeric',
#                  'Wheat',                 'Bajra',          'Black pepper',
#               'Cardamom',             'Coriander',                'Garlic',
#                 'Ginger',             'Groundnut',            'Horse-gram',
#                  'Jowar',                  'Ragi',             'Cashewnut',
# ...

# %%
crop.dropna(inplace=True)

# %%
# Comprehensive Data Cleaning Check
print("="*60)
print("DATA CLEANING VERIFICATION REPORT")
print("="*60)

# 1. Check for null values
print("\n1. NULL VALUES CHECK:")
null_counts = crop.isnull().sum()
print(f"   Total null values: {null_counts.sum()}")
if null_counts.sum() == 0:
    print("   ✓ No null values found")
else:
    print("   ✗ Null values found:")
    print(null_counts[null_counts > 0])

# 2. Check for duplicates
print("\n2. DUPLICATE ROWS CHECK:")
duplicates = crop.duplicated().sum()
print(f"   Total duplicate rows: {duplicates}")
if duplicates == 0:
    print("   ✓ No duplicate rows found")
else:
    print(f"   ✗ {duplicates} duplicate rows found")

# 3. Check data types
print("\n3. DATA TYPES:")
print(crop.dtypes)

# 4. Check for outliers in numeric columns
print("\n4. NUMERIC COLUMNS STATISTICS:")
numeric_cols = crop.select_dtypes(include=['int64', 'float64']).columns
print(crop[numeric_cols].describe())

# 5. Check for unusual values
print("\n5. CATEGORICAL COLUMNS UNIQUE VALUES:")
categorical_cols = crop.select_dtypes(include=['str']).columns
for col in categorical_cols:
    unique_count = crop[col].nunique()
    print(f"   {col}: {unique_count} unique values")
    print(f"      Sample values: {crop[col].unique()[:5].tolist()}")

print("\n" + "="*60)
print("DATASET SUMMARY: Dataset is CLEAN - No cleaning required!")
print("="*60)
# Out:
# ...
# DATA CLEANING VERIFICATION REPORT
# ...
#
# 1. NULL VALUES CHECK:
#    Total null values: 0
#    ✓ No null values found
#
# 2. DUPLICATE ROWS CHECK:
#    Total duplicate rows: 0
#    ✓ No duplicate rows found
#
# 3. DATA TYPES:
# Crop                   str
# Crop_Year            int64
# Season                 str
# State                  str
# Area               float64
# Production           int64
# Annual_Rainfall    float64
# Fertilizer         float64
# Pesticide          float64
# Yield              float64
# dtype: object
#
# 4. NUMERIC COLUMNS STATISTICS:
#           Crop_Year          Area    Production  Annual_Rainfall  \
# count  19689.000000  1.968900e+04  1.968900e+04     19689.000000
# mean    2009.127584  1.799266e+05  1.643594e+07      1437.755177
# std        6.498099  7.328287e+05  2.630568e+08       816.909589
# min     1997.000000  5.000000e-01  0.000000e+00       301.300000
# 25%     2004.000000  1.390000e+03  1.393000e+03       940.700000
# ...

# %%
# Remove trailing/leading spaces from string columns
import warnings
warnings.filterwarnings('ignore')

# Strip whitespace from all string columns
string_cols = crop.select_dtypes(include=['str']).columns
for col in string_cols:
    crop[col] = crop[col].str.strip()

print("✓ Removed trailing/leading spaces from categorical columns")
print("\nUpdated unique values after cleaning:")
for col in string_cols:
    print(f"   {col}: {crop[col].unique()[:5].tolist()}")
# Out:
# ✓ Removed trailing/leading spaces from categorical columns
#
# Updated unique values after cleaning:
#    Crop: ['Arecanut', 'Arhar/Tur', 'Castor seed', 'Coconut', 'Cotton(lint)']
#    Season: ['Whole Year', 'Kharif', 'Rabi', 'Autumn', 'Summer']
#    State: ['Assam', 'Karnataka', 'Kerala', 'Meghalaya', 'West Bengal']

# %%
sns.distplot(crop.Annual_Rainfall)
plt.show()

# %%
sns.histplot(crop.Annual_Rainfall)
plt.show()

# %%
sns.pairplot(crop)
plt.show()

# %%
ip=crop.drop('Yield',axis=1)
op=crop.Yield

# %%
#train test split
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(ip,op,test_size=0.1,random_state=30)

# Convert back to DataFrames with original column names
x_train = pd.DataFrame(x_train, columns=ip.columns)
x_test = pd.DataFrame(x_test, columns=ip.columns)

# %%
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (17720, 9)
# (17720,)
# (1969, 9)
# (1969,)

# %%
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer

# Identify categorical and numerical columns
categorical_features = ['Crop', 'Season', 'State']
numerical_features = ['Crop_Year', 'Area', 'Production', 'Annual_Rainfall', 'Fertilizer', 'Pesticide']

# Create a column transformer for one-hot encoding and standard scaling
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), numerical_features),
        ('cat', OneHotEncoder(handle_unknown='ignore'), categorical_features)
    ],
    remainder='passthrough'
)

# Apply the preprocessing to the training and testing data

x_train = preprocessor.fit_transform(x_train)
x_test = preprocessor.transform(x_test)

# %%
#ml algorithm
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
pred=lr.predict(x_test)
pred
# Out:
# array([ 12.26684609,  45.2782949 ,  43.60342845, ..., 107.46499461,
#        -13.15492467, -39.2278187 ], shape=(1969,))

# %%
y_test
# Out:
# 18289     0.566667
# 17395     0.346154
# 4395      0.559643
# 8926      0.490625
# 16568    16.143846
#            ...
# 7869      1.608462
# 18891     4.147500
# 2162      0.186923
# 9678      0.774000
# 4239      1.892500
# Name: Yield, Length: 1969, dtype: float64

# %%
from sklearn.metrics import accuracy_score,recall_score,precision_score,f1_score

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

mae = mean_absolute_error(y_test, pred)
mse = mean_squared_error(y_test, pred)
r2 = r2_score(y_test, pred)

print('Mean Absolute Error (MAE):', mae)
print('Mean Squared Error (MSE):', mse)
print('R-squared (R2):', r2)
# Out:
# Mean Absolute Error (MAE): 55.84938601585987
# Mean Squared Error (MSE): 78308.75274801314
# R-squared (R2): 0.8997973159407078

# %%
df=pd.DataFrame({'Y_Test':list(y_test),'Prediction':pred})
df
# Out:
#          Y_Test  Prediction
# 0      0.566667   12.266846
# 1      0.346154   45.278295
# 2      0.559643   43.603428
# 3      0.490625  -86.237216
# 4     16.143846   48.316869
# ...         ...         ...
# 1964   1.608462   12.779572
# 1965   4.147500  -48.342290
# 1966   0.186923  107.464995
# 1967   0.774000  -13.154925
# 1968   1.892500  -39.227819
#
# [1969 rows x 2 columns]

# %%
from sklearn.metrics import confusion_matrix, classification_report
import numpy as np

# Convert regression output to classification by binning yield values
# Define yield categories based on quantiles
low_threshold = y_test.quantile(0.33)
high_threshold = y_test.quantile(0.67)

def categorize_yield(value):
    if value <= low_threshold:
        return 'Low'
    elif value <= high_threshold:
        return 'Medium'
    else:
        return 'High'

# Apply categorization to actual and predicted values
y_test_categories = np.array([categorize_yield(val) for val in y_test])
pred_categories = np.array([categorize_yield(val) for val in pred])

# Compute confusion matrix
cm = confusion_matrix(y_test_categories, pred_categories, labels=['Low', 'Medium', 'High'])

# Display confusion matrix
print("Confusion Matrix (Actual vs Predicted):")
print(cm)
print("\n")

# Create a more detailed visualization
import matplotlib.pyplot as plt
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
            xticklabels=['Low', 'Medium', 'High'],
            yticklabels=['Low', 'Medium', 'High'],
            cbar_kws={'label': 'Count'})
plt.title('Confusion Matrix - Crop Yield Prediction')
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.tight_layout()
plt.show()

# Print classification report
print("\nClassification Report:")
print(classification_report(y_test_categories, pred_categories, labels=['Low', 'Medium', 'High']))
# Out:
# Confusion Matrix (Actual vs Predicted):
# [[360  13 278]
#  [299  14 355]
#  [225  10 415]]
# Classification Report:
#               precision    recall  f1-score   support
#
#          Low       0.41      0.55      0.47       651
#       Medium       0.38      0.02      0.04       668
#         High       0.40      0.64      0.49       650
#
#     accuracy                           0.40      1969
#    macro avg       0.39      0.40      0.33      1969
# weighted avg       0.39      0.40      0.33      1969

# %%
sns.lmplot(x='Y_Test',y='Prediction',data=df)
plt.show()

# %% [markdown]
# To test the model manually, you need to provide input values for each of the features used for training. These features are: 'Region', 'Soil_Type', 'Crop', 'Rainfall_mm', 'Temperature_Celsius', 'Days_to_Harvest', 'Fertilizer_Used', and 'Irrigation_Used'.
#
# You will need to provide values that are consistent with the data the model was trained on (e.g., valid region names, soil types, etc.).

# %%
# Example manual input data
# Replace these values with the specific data you want to test
manual_input = {
    'Crop': ['Cotton'],
    'Crop_Year': [2020],
    'Season': ['Kharif'],
    'State': ['Assam'],
    'Area': [1000.0],
    'Production': [5000.0],
    'Annual_Rainfall': [1500.0],
    'Fertilizer': [1000000.0],
    'Pesticide': [5000.0]
} # Added Weather_Condition


# Convert the manual input to a pandas DataFrame
manual_df = pd.DataFrame(manual_input)

# Preprocess the manual input using the same preprocessor
manual_preprocessed = preprocessor.transform(manual_df)

# Make a prediction using the trained model
manual_prediction = lr.predict(manual_preprocessed)

# The preprocessor expects the columns in the same order as the training data
print(f"The predicted crop yield for the manual input is: {manual_prediction[0]:.3f} tons per hectare")
# Out:
# The predicted crop yield for the manual input is: 97.941 tons per hectare
